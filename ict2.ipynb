# %% [markdown]
# <a href="https://colab.research.google.com/github/bismishafi/advanced-in-python/blob/main/ict2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=20
education="higher secondary"
if age>18:
  if education=="higher secondary":
    print(" you are eligible for college")
  else:
    print("you are not eligible for college, but continue with higher education")
else:
  print("you are not eligible for college")
# Out:
#  you are eligible for college

# %%
x=10
if x>5:
    print("greater")
else:
    print("smaller")
# Out:
# greater

# %%
print("greater")if x>5 else print("smaller")
# Out:
# greater

# %%
mark=45
result="pass" if mark>30 else "fail"
if result=="pass":
    print("awarded with a grade")
else:
    print("no award")
# Out:
# awarded with a grade

# %%
temperature=32
weather={"status":"hot" if temperature>30 else "cold"}
weather
# Out:
# {'status': 'hot'}

# %%
print("apple :350\n bingo54\n orange:30\n pen:34\n pencil:90\n")
a=[38,54,30,90]
t=sum(a)
if(t>=2000):
  dis=(t/100)*20
  f=t-dis
elif(t>= 1000):
  dis=(t/100)*10
  f=t-dis
else:
  dis=0
  f=t

print("dis=", dis)
print("total=",f)
# Out:
# apple :350
#  bingo54
#  orange:30
#  pen:34
#  pencil:90
#
# dis= 0
# total= 212

# %%
for i in range (10):
  print(f"square of (i) is {i**2}")
# Out:
# square of (i) is 0
# square of (i) is 1
# square of (i) is 4
# square of (i) is 9
# square of (i) is 16
# square of (i) is 25
# square of (i) is 36
# square of (i) is 49
# square of (i) is 64
# square of (i) is 81

# %%
grocery_list = ["apples","bananas","milk","bread","egg"]
for i in grocery_list:
  print(i)
# Out:
# apples
# bananas
# milk
# bread
# egg

# %%
grocery_list=["apples","bananas","milk","bread","eggs"]
for i in grocery_list: # Changed 'f' to 'grocery_list'
  if i=="milk": # Added colon
    print("milk found")
  else:
    print("milk not found")
# Out:
# milk not found
# milk not found
# milk found
# milk not found
# milk not found

# %%
for item in grocery_list:
  if item =="milk":
    print(item ,"present")
    break
  else:
    if item=="eggs":
      print(item, not "present")
# Out:
# milk present

# %%
savings = [2000,2500,0,3000,1000,5000]
total = 0
for i in savings:
  if i==0:
    continue
    t=i
    print(i)
  total+=i
print("total savings (excluding zero):",total)
# Out:
# total savings (excluding zero): 13500

# %%
savings=[2000,2500,0,3000,1000,5000]
total=0
for i in savings:
  if i==0:
    continue
    t=i
  print(i)
  if i>4000:
    print(f"4000<{i}")
    print(f"total savings is {t}")
# Out:
# 2000
# 2500
# 3000
# 1000
# 5000
# 4000<5000
# total savings is 13500

# %%
savings=[2000,2500,0,3000,1000,5000]
total=0
for i in savings:
  if i==0:
    continue
    print(i)
  print(i)
  if i>4000:
    print(f"4000<{i}")
    t = sum(savings)
    print(f"total saving is {t}")
    tuple(savings)
# Out:
# 2000
# 2500
# 3000
# 1000
# 5000
# 4000<5000
# total saving is 13500

# %%
set(savings)
# Out:
# {0, 1000, 2000, 2500, 3000, 5000}

# %%
list(savings)
# Out:
# [2000, 2500, 0, 3000, 1000, 5000]

# %%
numbers=["987643210","12345","9988776655","9876501234","93847837823"]
for i in numbers:
    if len(i)==10:
      print(i)
# Out:
# 9988776655
# 9876501234

# %%
["987643210","12345","9988776655","9876501234","93847837823"]
for i in numbers:
  if len(i)==10:
    print(f"{i} is valid")
  else:
    print(f"{i} is invalid")
# Out:
# 987643210 is invalid
# 12345 is invalid
# 9988776655 is valid
# 9876501234 is valid
# 93847837823 is invalid

# %%
numbers=["987643210","12345","9988776655","9876501234","93847837823"]
invalid_count=0
valid_count=0
valid_nums=set()
for num in numbers:
  if len(num)!=10:
    print("invalid")
    invalid_count+=1
    continue
  print("valid")
  valid_count+=1
  valid_nums.add(num)
print(f"invalid count is {invalid_count} and valid is {valid_count}")
print(valid_nums)
# Out:
# invalid
# invalid
# valid
# valid
# invalid
# invalid count is 3 and valid is 2
# {'9988776655', '9876501234'}

# %%
i=1
while i<10:
  print(i**1)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
savings_goal=10000
current_sav=0

monthly_dep=1500


months=0
while current_sav <savings_goal:
  current_sav+=monthly_dep
  months+=1
else:
  print("you reach your goal")
  print(f"it will take {months}to achieve your goal of{savings_goal}")
# Out:
# you reach your goal
# it will take 7to achieve your goal of10000

# %%
student_grades={"anu":85,"bob":63,"sam":55,"ryan":52}
for i in student_grades.keys():
  print(i)
# Out:
# anu
# bob
# sam
# ryan

# %%
for i,j in student_grades.items():
 print(i,":",j)
# Out:
# anu : 85
# bob : 63
# sam : 55
# ryan : 52

# %%
for i,j in student_grades.items():
  if j>50:
    print(f"{i} scored a grade")
  else: # Corrected indentation
    print(f"{i}scored b grade")
# Out:
# anu scored a grade
# bob scored a grade
# sam scored a grade
# ryan scored a grade

# %%
employees = {} # Initializing employees dictionary
for empcode,empdetail in employees.items():
  print(empdetail)

# %%
for empcode,empdetail in employees.items():
  for k,val in empdetail.items():
    print(k,":",val)

# %%
a=3
b=4
c=5
if a>b:
  print("a is largest")
elif b>c:
  print("b is largest")
else:
  print("c is largest")
# Out:
# c is largest

# %%
for number in range (100,800) :
  if number%3 ==0 and number%7==0:
    print(number)
# Out:
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# 252
# 273
# 294
# 315
# 336
# 357
# 378
# 399
# 420
# 441
# 462
# 483
# 504
# 525
# 546
# 567
# 588
# 609
# 630
# 651
# 672
# 693
# 714
# 735
# 756
# 777
# 798

# %% [markdown]
# to construct the pattern using for loop

# %%
for i in range(1,6):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# using for loop that will iterate from 1 to 15.odd/even

# %%
for i in range(1,6):
  if i%2==0:
    print(i,"-even")
  else:
    print(i,"-odd")
# Out:
# 1 -odd
# 2 -even
# 3 -odd
# 4 -even
# 5 -odd

# %% [markdown]
# integer as i/p and calculated the sum of its digits

# %%
num=int(input("enter a integer"))
sum=0
while num>0:
  digit=num%10
  sum=sum+digit
  num=num//10
print("sum of digits is",sum)
# Out:
# enter a integer1234
# sum of digits is 10

# %%
def factorial(n):
    fact=1
    for i in range (1,n+1):
      fact *=i
    return fact
num=int(input("enter a number:"))
print("factorial:",factorial(num))
# Out:
# enter a number:54
# factorial: 230843697339241380472092742683027581083278564571807941132288000000000000

# %%
sentence=input("enter a sequence :").lower()
vowels="aeiou"
vowel_count=0
consonant_count=0

for char in sentence:
    if char.isalpha():
        if char in vowels:
            vowel_count+=1
        else:
            consonant_count+=1
print("vowels:",vowel_count)
print("consonants:",consonant_count)
# Out:
# enter a sequence :my dog has blue eyes
# vowels: 6
# consonants: 10

# %%
text=input("enter a string")
freq={}

for char in text:
  freq[char]=freq.get(char,0)+1
print("character frequency")
for char,count in freq.items():
  print(char,":",count)
# Out:
# enter a string"hello"
# character frequency
# " : 2
# h : 1
# e : 1
# l : 2
# o : 1

# %%
import math

a=float(input("enter a:"))
b=float(input("enter b:"))
c=float(input("enter c:"))

discriminant=b**2-4*a*c
if discriminant>0:
  root1=(-b+ math.sqrt(discriminant))/(2*a)
  root2=(-b- math.sqrt(discriminant))/(2*a)
  print("roots are real and different:",root1,root2)
elif discriminant == 0:
  root1=-b/(2*a)
  print("roots are real and same:",root1)
else:
  print("roots are complex")
# Out:
# enter a:5
# enter b:8
# enter c:6
# roots are complex

# %%
def multiply(num):
  print(num*2)
multiply(10)
# Out:
# 20

# %%
def send_gift(recipient, gift):
  print(f"sending {gift} to {recipient}")

send_gift("alice", "a watch")
# Out:
# sending a watch to alice

# %% [markdown]
# positional argument

# %%
def book_trip(destination,transport):
    print(f"booking {destination} to {transport}")
book_trip("a flight","paris")
# Out:
# booking a flight to paris

# %% [markdown]
# keyword argument

# %%
def book_trip(destination,transport):
    print(f"booking {transport} to {destination}!")
book_trip(destination="paris",transport="train")
# Out:
# booking train to paris!

# %% [markdown]
# default

# %%
def book_trip(destination,transport="paris"):
    print(f"booking a {destination} to {transport}")
book_trip("flight" ,"paris")
# Out:
# booking a flight to paris

# %%
def book_trip(destination,*items):
    print(f"trip to {destination}.packing:{items}")
book_trip("london","hat","pen")
# Out:
# trip to london.packing:('hat', 'pen')

# %% [markdown]
# function with return value

# %%
 def add_numbers(a,b):
     print(a+b)
result=add_numbers(5,5)
# Out:
# 10

# %%
def add_ten(number):
    print(number+10)
my_result=add_ten(5)
final_answer=my_result*2
print("the final answer is :{final_answe}")
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-962715322.py in <cell line: 0>()
#       2     print(number+10)
#       3 my_result=add_ten(5)
# ----> 4 final_answer=my_result*2
#       5 print("the final answer is :{final_answe}")
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
def add_ten(number):
    return number+10
my_result=add_ten(5)
final_answer=my_result*2
print(f"the final answer is :{final_answer}")
# Out:
# the final answer is :30

# %%
square=lambda x:x*x
square(5)
# Out:
# 25

# %%
addition=lambda x,y:x+y
addition(10,20)
# Out:
# 30

# %%
is_pass=lambda marks:"pass"if marks>40 else "fail"
is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq=x*x
  return sq

numbers=[1,2,3,4,5]
squares=map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
sq=lambda x:x*x
numbers=[1,2,3,4,5]
squares=map(sq,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
squares=list(map(lambda x:x*x,numbers))
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a=[1,2,3]
list_b=[4,5,6]
sum_lists=list(map(lambda x,y:x+y,list_a,list_b))
sum_lists
# Out:
# [5, 7, 9]

# %% [markdown]
# filter out negative values using lambda

# %%
number=[-3,-2,-7,9,4,8,1,5]
positive_numbers=list(filter(lambda x:x>0,numbers))
positive_numbers
# Out:
# [1, 2, 3, 4, 5]
